# %% [markdown]
# # 📥 Kaggle Datasets to Google Drive
# Run each cell step by step.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()  # Upload kaggle.json

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
import os
base_path = '/content/drive/MyDrive/kaggle_datasets'
os.makedirs(base_path, exist_ok=True)

# %% [markdown]
# ## Download Datasets

# %%
datasets = [
    'muratkokludataset/rice-image-dataset',
    'filippoo/deep-learning-az-ann'
]

for ds in datasets:
    name = ds.split('/')[-1]
    # !kaggle datasets download -d {ds} -p /content/
    # !unzip -q /content/{name}.zip -d /content/{name}
    # !mv /content/{name} '/content/drive/MyDrive/kaggle_datasets/'

# %%
# !ls /content/drive/MyDrive/kaggle_datasets
